# %%
import networkx as nx
import matplotlib.pyplot as plt

# Example adjacency list
# This is a dictionary where each key is a node and the value is a list of adjacent nodes
adj_list = {
    'Play song': ['Open TV', 'Navigate to Smart Tube', 'Choose song'],
    'Open TV': ['Switch on socket', 'Switch on TV'],
    'Navigate to Smart Tube': ['Scroll down', 'Select Smart Tube'],
    'Choose song': ['Go to search bar', 'Type song name', 'Press enter'],
    'Go to search bar': ['Move cursor to search bar', 'Press enter'],
}

# Create an empty graph
G = nx.Graph()

# Add nodes and edges from the adjacency list
for node, neighbors in adj_list.items():
    for neighbor in neighbors:
        G.add_edge(node, neighbor)

# Draw the graph
# plt.figure(figsize=(8, 6))
# nx.draw(G, pos=nx.shell_layout(G),with_labels=True, node_color='lightblue', node_size=500, font_size=10, font_weight='bold', edge_color='gray')
# plt.title("Graph Visualization")
# plt.show()


layouts = {
    "circular_layout": nx.circular_layout,
    "kamada_kawai_layout": nx.kamada_kawai_layout,
    "planar_layout": nx.planar_layout,
    "random_layout": nx.random_layout,
    "shell_layout": nx.shell_layout,
    "spectral_layout": nx.spectral_layout,
    "spring_layout": nx.spring_layout
}

# Plot each layout
for layout_name, layout_func in layouts.items():
    plt.figure(figsize=(8, 6))
    pos = layout_func(G)
    nx.draw(
        G, pos, with_labels=True,
        node_color='skyblue', node_size=700, node_shape='o',
        font_size=14, font_color='black', font_weight='bold',
        edge_color='gray', width=2, style='solid'
    )
    plt.title(f"Graph Visualization using {layout_name}")
    plt.show()

# %%
import networkx as nx
from pyvis.network import Network

# Example adjacency list
adj_list = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['C', 'E']
}

# Create a NetworkX graph
G = nx.Graph()

# Add nodes and edges from the adjacency list
for node, neighbors in adj_list.items():
    for neighbor in neighbors:
        G.add_edge(node, neighbor)

# Create a PyVis network
net = Network(notebook=True, cdn_resources='in_line')

# Convert NetworkX graph to PyVis network
net.from_nx(G)

# Customize the network appearance
net.show_buttons(filter_=['nodes', 'edges', 'physics'])
net.set_options("""
const options = {
  "nodes": {
    "color": {
      "border": "rgba(0,0,0,1)",
      "background": "rgba(97,189,241,1)"
    },
    "font": {
      "size": 14,
      "color": "rgba(0,0,0,1)"
    }
  },
  "edges": {
    "color": {
      "color": "rgba(100,100,100,1)"
    },
    "arrows": {
      "to": {
        "enabled": false
      }
    },
    "smooth": {
      "enabled": true,
      "type": "continuous"
    }
  },
  "physics": {
    "forceAtlas2Based": {
      "gravitationalConstant": -50,
      "centralGravity": 0.01,
      "springLength": 100,
      "springConstant": 0.08,
      "damping": 0.4,
      "avoidOverlap": 0.8
    },
    "minVelocity": 0.75,
    "solver": "forceAtlas2Based"
  }
}
""")

# Show the network
net.show("graph.html")
# Out:
# graph.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
